# %%
# np.matmul()
# np.dot()
# Pre_Season_Batter
import pandas as pd
preseason_df = pd.read_csv("데이터셋/KBO/Pre_Season_Batter.csv")
# Regular_Season_Batter
regular_season_df = pd.read_csv("데이터셋/KBO/Regular_Season_Batter.csv")

print("preseason_df.shape : ", preseason_df.shape)
print("regular_season_df.shape : ", regular_season_df.shape)
# Out:
# preseason_df.shape :  (1393, 29)
# regular_season_df.shape :  (2454, 29)

# %%
regular_season_df.head()
# Out:
#    batter_id batter_name  year team    avg    G   AB   R   H  2B  ...  GDP  \
# 0          0        가르시아  2018   LG  0.339   50  183  27  62   9  ...    3
# 1          1         강경학  2011   한화  0.000    2    1   0   0   0  ...    0
# 2          1         강경학  2014   한화  0.221   41   86  11  19   2  ...    1
# 3          1         강경학  2015   한화  0.257  120  311  50  80   7  ...    3
# 4          1         강경학  2016   한화  0.158   46  101  16  16   3  ...    5
#
#      SLG    OBP   E  height/weight      year_born   position  \
# 0  0.519  0.383   9     177cm/93kg  1985년 04월 12일  내야수(우투우타)
# 1  0.000  0.000   1     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 2  0.349  0.337   6     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 3  0.325  0.348  15     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 4  0.257  0.232   7     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
#
#                                    career  starting_salary    OPS
# 0  쿠바 Ciego de Avila Maximo Gomez Baez(대)              NaN  0.902
# ...

# %%
regular_season_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2454 entries, 0 to 2453
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   batter_id        2454 non-null   int64
#  1   batter_name      2454 non-null   object
#  2   year             2454 non-null   int64
#  3   team             2454 non-null   object
#  4   avg              2428 non-null   float64
#  5   G                2454 non-null   int64
#  6   AB               2454 non-null   int64
#  7   R                2454 non-null   int64
#  8   H                2454 non-null   int64
#  9   2B               2454 non-null   int64
#  10  3B               2454 non-null   int64
#  11  HR               2454 non-null   int64
#  12  TB               2454 non-null   int64
#  13  RBI              2454 non-null   int64
#  14  SB               2454 non-null   int64
#  15  CS               2454 non-null   int64
#  16  BB               2454 non-null   int64
# ...

# %%
regular_season_df['new_idx'] = regular_season_df['batter_name'] + regular_season_df['year'].apply(str)  #숫자인 year를 문자로 적용시켜줌.(문자+숫자 x , 문자+문자 o) 정규시즌

# %%
preseason_df['new_idx'] = preseason_df['batter_name'] + preseason_df['year'].apply(str)  #숫자인 year를 문자로 적용시켜줌.(문자+숫자 x , 문자+문자 o) 프리시즌

# %%
regular_season_df['new_idx']
# Out:
# 0       가르시아2018
# 1        강경학2011
# 2        강경학2014
# 3        강경학2015
# 4        강경학2016
#           ...
# 2449     황진수2014
# 2450     황진수2015
# 2451     황진수2016
# 2452     황진수2017
# 2453     황진수2018
# Name: new_idx, Length: 2454, dtype: object

# %%
preseason_df['new_idx']
# Out:
# 0       가르시아2018
# 1        강경학2011
# 2        강경학2014
# 3        강경학2015
# 4        강경학2016
#           ...
# 1388     황재균2014
# 1389     황재균2015
# 1390     황재균2016
# 1391     황재균2018
# 1392     황진수2014
# Name: new_idx, Length: 1393, dtype: object

# %%
intersection_idx = list(set(regular_season_df['new_idx']).intersection(preseason_df['new_idx']))       # a.intersection(b) ---> a와 b교집합

# %%
intersection_idx
# Out:
# ['홍성갑2016',
#  '이상호2017',
#  '정상호2015',
#  '정주현2009',
#  '박용택2014',
#  '김상수2011',
#  '이동훈2017',
#  '전준우2017',
#  '민병헌2017',
#  '강민국2014',
#  '김재율2012',
#  '이범호2015',
#  '오재원2017',
#  '조홍석2013',
#  '조동찬2007',
#  '오지환2018',
#  '김민성2013',
#  '이준수2018',
#  '양성우2016',
#  '손시헌2009',
#  '이재원2008',
#  '강민호2008',
#  '문선재2015',
#  '정성훈2006',
#  '유한준2014',
#  '정근우2014',
#  '정근우2013',
#  '안치홍2018',
#  '유강남2017',
#  '정진호2012',
#  '최주환2016',
#  '황재균2009',
#  '김강민2012',
#  '정진기2017',
#  '이대호2002',
#  '김헌곤2018',
#  '송광민2018',
#  '이진영2006',
#  '양성우2018',
#  '박한이2009',
#  '나지완2009',
#  '한승택2018',
#  '박석민2014',
#  '김태완2014',
#  '황윤호2016',
#  '오재일2016',
#  '러프2018',
#  '호잉2018',
#  '남태혁2016',
#  '문규현2015',
#  '박헌도2014',
#  '김태완2010',
#  '김재성2015',
#  '윤석민2017',
#  '이영욱2010',
#  '홍성갑2015',
#  '나지완2008',
#  '강민호2005',
#  '오재원2015',
#  '정범모2006',
#  '박한이2006',
#  '김강민2008',
#  '김태균2016',
#  '도태훈2016',
#  '오재원2010',
#  '오정복2011',
#  '배영섭2017',
#  '신종길2012',
#  '이대수2008',
#  '손아섭2018',
#  '이대호2011',
# ...

# %%
(lambda x:x+3)(3) #람다식
# Out:
# 6

# %%
regular_season_new  =  regular_season_df.loc[regular_season_df['new_idx'].apply(lambda x : x in intersection_idx)]

# %%
preseason_df_new  =  preseason_df.loc[preseason_df['new_idx'].apply(lambda x : x in intersection_idx)]
preseason_df_new = preseason_df_new.sort_values(by = 'new_idx').reset_index(drop = True)

# %%
regular_season_df['new_idx'].apply(lambda x : x in intersection_idx)[-10:]
# Out:
# 2444     True
# 2445    False
# 2446    False
# 2447    False
# 2448    False
# 2449     True
# 2450    False
# 2451    False
# 2452    False
# 2453    False
# Name: new_idx, dtype: bool

# %%
regular_season_new[-10:] # ---> index 값이 안맞음
# Out:
#       batter_id batter_name  year  team    avg    G   AB   R    H  2B  ...  \
# 2436        342         황재균  2009  히어로즈  0.284  133  536  86  152  27  ...
# 2437        342         황재균  2010    롯데  0.225   94  306  41   69  14  ...
# 2438        342         황재균  2011    롯데  0.289  117  398  62  115  18  ...
# 2439        342         황재균  2012    롯데  0.272  133  448  42  122  19  ...
# 2440        342         황재균  2013    롯데  0.274  128  489  70  134  29  ...
# 2441        342         황재균  2014    롯데  0.321  128  486  66  156  33  ...
# 2442        342         황재균  2015    롯데  0.290  144  534  95  155  41  ...
# 2443        342         황재균  2016    롯데  0.335  127  498  97  167  26  ...
# 2444        342         황재균  2018    KT  0.296  142  530  76  157  41  ...
# 2449        344         황진수  2014    롯데  0.000    5    5   0    0   0  ...
#
#         SLG    OBP   E  height/weight      year_born   position  \
# 2436  0.453  0.349  12     183cm/96kg  1987년 07월 28일  내야수(우투우타)
# ...

# %%
regular_season_new.sort_values(by = 'new_idx')
# Out:
#       batter_id batter_name  year team    avg    G   AB   R    H  2B  ...  \
# 0             0        가르시아  2018   LG  0.339   50  183  27   62   9  ...
# 1             1         강경학  2011   한화  0.000    2    1   0    0   0  ...
# 2             1         강경학  2014   한화  0.221   41   86  11   19   2  ...
# 3             1         강경학  2015   한화  0.257  120  311  50   80   7  ...
# 4             1         강경학  2016   한화  0.158   46  101  16   16   3  ...
# ...         ...         ...   ...  ...    ...  ...  ...  ..  ...  ..  ...
# 2441        342         황재균  2014   롯데  0.321  128  486  66  156  33  ...
# 2442        342         황재균  2015   롯데  0.290  144  534  95  155  41  ...
# 2443        342         황재균  2016   롯데  0.335  127  498  97  167  26  ...
# 2444        342         황재균  2018   KT  0.296  142  530  76  157  41  ...
# 2449        344         황진수  2014   롯데  0.000    5    5   0    0   0  ...
#
#         SLG    OBP   E  height/weight      year_born   position  \
# ...

# %%
regular_season_new.sort_values(by = 'new_idx').reset_index(drop = False)
# Out:
#       index  batter_id batter_name  year team    avg    G   AB   R    H  ...  \
# 0         0          0        가르시아  2018   LG  0.339   50  183  27   62  ...
# 1         1          1         강경학  2011   한화  0.000    2    1   0    0  ...
# 2         2          1         강경학  2014   한화  0.221   41   86  11   19  ...
# 3         3          1         강경학  2015   한화  0.257  120  311  50   80  ...
# 4         4          1         강경학  2016   한화  0.158   46  101  16   16  ...
# ...     ...        ...         ...   ...  ...    ...  ...  ...  ..  ...  ...
# 1353   2441        342         황재균  2014   롯데  0.321  128  486  66  156  ...
# 1354   2442        342         황재균  2015   롯데  0.290  144  534  95  155  ...
# 1355   2443        342         황재균  2016   롯데  0.335  127  498  97  167  ...
# 1356   2444        342         황재균  2018   KT  0.296  142  530  76  157  ...
# 1357   2449        344         황진수  2014   롯데  0.000    5    5   0    0  ...
#
# ...

# %%
regular_season_new = regular_season_new.sort_values(by = 'new_idx').reset_index(drop = True) #sort_values(by = '열') ---> 그 열에 기준으로 정렬
                                                                                             #reset_index(drop = True) ---> drop은 그전 뒤죽박죽인 인덱스를 빼고 reset_index로 새로운 순차적인 index가 추가

# %%
regular_season_new
# Out:
#       batter_id batter_name  year team    avg    G   AB   R    H  2B  ...  \
# 0             0        가르시아  2018   LG  0.339   50  183  27   62   9  ...
# 1             1         강경학  2011   한화  0.000    2    1   0    0   0  ...
# 2             1         강경학  2014   한화  0.221   41   86  11   19   2  ...
# 3             1         강경학  2015   한화  0.257  120  311  50   80   7  ...
# 4             1         강경학  2016   한화  0.158   46  101  16   16   3  ...
# ...         ...         ...   ...  ...    ...  ...  ...  ..  ...  ..  ...
# 1353        342         황재균  2014   롯데  0.321  128  486  66  156  33  ...
# 1354        342         황재균  2015   롯데  0.290  144  534  95  155  41  ...
# 1355        342         황재균  2016   롯데  0.335  127  498  97  167  26  ...
# 1356        342         황재균  2018   KT  0.296  142  530  76  157  41  ...
# 1357        344         황진수  2014   롯데  0.000    5    5   0    0   0  ...
#
#         SLG    OBP   E  height/weight      year_born   position  \
# ...

# %%
preseason_df_new.shape
# Out:
# (1358, 30)

# %%
regular_season_new.shape
# Out:
# (1358, 30)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
plt.plot(regular_season_new['OPS'], 'o', color = 'orange')
plt.title("regular_season_new['OPS']")
plt.xlabel('index')
plt.ylabel('OPS')
plt.grid()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
plt.plot(preseason_df_new['OPS'], 'o', color = 'red')
plt.title("regular_season_new['OPS']")
plt.xlabel('index')
plt.ylabel('OPS')
plt.grid()

# %%
corr = regular_season_new['OPS'].corr(preseason_df_new['OPS'])
import seaborn as sns

# %%
import numpy as np
sns.regplot(x = regular_season_new['OPS'],
            y = preseason_df_new['OPS'],
            fit_reg = True,
            color = 'green')
plt.title('Corr : {}'.format(np.round(corr,3)),fontsize = 30)
plt.xlabel("Regular Season OPS", fontsize=12)
plt.ylabel("Preseason New OPS", fontsize=12)

plt.grid()
plt.show()

# %%
regular_season_df = pd.read_csv('데이터셋/KBO/Regular_Season_Batter.csv')
regular_season_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2454 entries, 0 to 2453
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   batter_id        2454 non-null   int64
#  1   batter_name      2454 non-null   object
#  2   year             2454 non-null   int64
#  3   team             2454 non-null   object
#  4   avg              2428 non-null   float64
#  5   G                2454 non-null   int64
#  6   AB               2454 non-null   int64
#  7   R                2454 non-null   int64
#  8   H                2454 non-null   int64
#  9   2B               2454 non-null   int64
#  10  3B               2454 non-null   int64
#  11  HR               2454 non-null   int64
#  12  TB               2454 non-null   int64
#  13  RBI              2454 non-null   int64
#  14  SB               2454 non-null   int64
#  15  CS               2454 non-null   int64
#  16  BB               2454 non-null   int64
# ...

# %%
regular_season_df['height/weight'][10:20]
# Out:
# 10    180cm/82kg
# 11    180cm/82kg
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# Name: height/weight, dtype: object

# %%
regular_season_HW_OPS = regular_season_df[['height/weight','OPS','OBP','SLG']]

# %%
regular_season_HW_OPS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2454 entries, 0 to 2453
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   height/weight  1652 non-null   object
#  1   OPS            2428 non-null   float64
#  2   OBP            2430 non-null   float64
#  3   SLG            2428 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 76.8+ KB

# %%
regular_season_HW_OPS = regular_season_HW_OPS.dropna(axis=0) #결측치 있는 값 날리기
regular_season_HW_OPS
# Out:
#      height/weight    OPS    OBP    SLG
# 0       177cm/93kg  0.902  0.383  0.519
# 1       180cm/72kg  0.000  0.000  0.000
# 2       180cm/72kg  0.686  0.337  0.349
# 3       180cm/72kg  0.673  0.348  0.325
# 4       180cm/72kg  0.489  0.232  0.257
# ...            ...    ...    ...    ...
# 2449    181cm/82kg  0.000  0.000  0.000
# 2450    181cm/82kg  0.000  0.000  0.000
# 2451    181cm/82kg  0.000  0.000  0.000
# 2452    181cm/82kg  0.761  0.359  0.402
# 2453    181cm/82kg  0.564  0.231  0.333
#
# [1634 rows x 4 columns]

# %%
regular_season_HW_OPS.info() #위에 인덱스는 2453까지 근데 민테 1634까지 인덱스 맞지않음.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1634 entries, 0 to 2453
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   height/weight  1634 non-null   object
#  1   OPS            1634 non-null   float64
#  2   OBP            1634 non-null   float64
#  3   SLG            1634 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 63.8+ KB

# %%
regular_season_HW_OPS = regular_season_HW_OPS.reset_index(drop = True)

# %%
regular_season_HW_OPS
# Out:
#      height/weight    OPS    OBP    SLG
# 0       177cm/93kg  0.902  0.383  0.519
# 1       180cm/72kg  0.000  0.000  0.000
# 2       180cm/72kg  0.686  0.337  0.349
# 3       180cm/72kg  0.673  0.348  0.325
# 4       180cm/72kg  0.489  0.232  0.257
# ...            ...    ...    ...    ...
# 1629    181cm/82kg  0.000  0.000  0.000
# 1630    181cm/82kg  0.000  0.000  0.000
# 1631    181cm/82kg  0.000  0.000  0.000
# 1632    181cm/82kg  0.761  0.359  0.402
# 1633    181cm/82kg  0.564  0.231  0.333
#
# [1634 rows x 4 columns]

# %%
#height/weight ---> 값 따로 떨어뜨리기

df_row1 = [] 
for i in range(len(regular_season_HW_OPS)):
    df_row1.append(regular_season_HW_OPS['height/weight'][i].replace('cm',''))

print(df_row1)
# Out:
# ['177/93kg', '180/72kg', '180/72kg', '180/72kg', '180/72kg', '180/72kg', '180/72kg', '180/82kg', '180/82kg', '180/82kg', '180/82kg', '180/82kg', '176/80kg', '176/80kg', '176/80kg', '176/80kg', '185/100kg', '185/100kg', '185/100kg', '185/100kg', '185/100kg', '185/100kg', '185/100kg', '185/100kg', '185/100kg', '185/100kg', '185/100kg', '185/100kg', '185/100kg', '185/100kg', '185/100kg', '184/98kg', '172/64kg', '172/64kg', '179/77kg', '179/77kg', '179/77kg', '180/81kg', '180/81kg', '180/81kg', '181/66kg', '181/66kg', '181/66kg', '181/66kg', '181/66kg', '178/68kg', '184/83kg', '184/83kg', '184/83kg', '184/83kg', '184/83kg', '184/83kg', '189/75kg', '189/75kg', '189/75kg', '189/75kg', '180/94kg', '180/94kg', '180/94kg', '180/94kg', '180/94kg', '180/88kg', '180/88kg', '180/88kg', '177/85kg', '177/85kg', '177/85kg', '177/85kg', '177/85kg', '182/85kg', '182/85kg', '182/85kg', '182/85kg', '182/85kg', '182/85kg', '182/85kg', '182/85kg', '182/85kg', '182/85kg', '182/85kg', '182/85kg', '182/85kg'
# ...

# %%
df_row2 = []
for i in range(len(df_row1)):
    df_row2.append(df_row1[i].replace('kg',''))
    
print(df_row2)
# Out:
# ['177/93', '180/72', '180/72', '180/72', '180/72', '180/72', '180/72', '180/82', '180/82', '180/82', '180/82', '180/82', '176/80', '176/80', '176/80', '176/80', '185/100', '185/100', '185/100', '185/100', '185/100', '185/100', '185/100', '185/100', '185/100', '185/100', '185/100', '185/100', '185/100', '185/100', '185/100', '184/98', '172/64', '172/64', '179/77', '179/77', '179/77', '180/81', '180/81', '180/81', '181/66', '181/66', '181/66', '181/66', '181/66', '178/68', '184/83', '184/83', '184/83', '184/83', '184/83', '184/83', '189/75', '189/75', '189/75', '189/75', '180/94', '180/94', '180/94', '180/94', '180/94', '180/88', '180/88', '180/88', '177/85', '177/85', '177/85', '177/85', '177/85', '182/85', '182/85', '182/85', '182/85', '182/85', '182/85', '182/85', '182/85', '182/85', '182/85', '182/85', '182/85', '182/85', '182/85', '182/85', '182/85', '188/85', '188/85', '184/80', '184/80', '184/80', '184/80', '184/80', '184/80', '184/80', '186/101', '186/101', '186/101', '183/89',
# ...

# %%
df_row3 = []
for i in range(len(df_row2)):
    df_row3.append(df_row2[i].split('/'))

print(df_row3)
# Out:
# [['177', '93'], ['180', '72'], ['180', '72'], ['180', '72'], ['180', '72'], ['180', '72'], ['180', '72'], ['180', '82'], ['180', '82'], ['180', '82'], ['180', '82'], ['180', '82'], ['176', '80'], ['176', '80'], ['176', '80'], ['176', '80'], ['185', '100'], ['185', '100'], ['185', '100'], ['185', '100'], ['185', '100'], ['185', '100'], ['185', '100'], ['185', '100'], ['185', '100'], ['185', '100'], ['185', '100'], ['185', '100'], ['185', '100'], ['185', '100'], ['185', '100'], ['184', '98'], ['172', '64'], ['172', '64'], ['179', '77'], ['179', '77'], ['179', '77'], ['180', '81'], ['180', '81'], ['180', '81'], ['181', '66'], ['181', '66'], ['181', '66'], ['181', '66'], ['181', '66'], ['178', '68'], ['184', '83'], ['184', '83'], ['184', '83'], ['184', '83'], ['184', '83'], ['184', '83'], ['189', '75'], ['189', '75'], ['189', '75'], ['189', '75'], ['180', '94'], ['180', '94'], ['180', '94'], ['180', '94'], ['180', '94'], ['180', '88'], ['180', '88'], ['180', '88'], ['177', '85'], ['177',
# ...

# %%
df_H = []

for i in range(len(df_row3)):
    df_H.append(df_row3[i][0])
    
    
df_W = []
for i in range(len(df_row3)):
    df_W.append(df_row3[i][1])
    
print(df_H[:10])
print(df_W[:10])
# Out:
# ['177', '180', '180', '180', '180', '180', '180', '180', '180', '180']
# ['93', '72', '72', '72', '72', '72', '72', '82', '82', '82']

# %%
regular_season_HW_OPS['Height'] = df_H
regular_season_HW_OPS['Weight'] = df_W

# %%
regular_season_HW_OPS[:10]
# Out:
#   height/weight    OPS    OBP    SLG Height Weight
# 0    177cm/93kg  0.902  0.383  0.519    177     93
# 1    180cm/72kg  0.000  0.000  0.000    180     72
# 2    180cm/72kg  0.686  0.337  0.349    180     72
# 3    180cm/72kg  0.673  0.348  0.325    180     72
# 4    180cm/72kg  0.489  0.232  0.257    180     72
# 5    180cm/72kg  0.552  0.290  0.262    180     72
# 6    180cm/72kg  0.774  0.382  0.392    180     72
# 7    180cm/82kg  0.000  0.000  0.000    180     82
# 8    180cm/82kg  0.600  0.200  0.400    180     82
# 9    180cm/82kg  0.000  0.000  0.000    180     82

# %%
regular_season_HW_OPS.info() # 숫자가 다 문자로 들어가잇음
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1634 entries, 0 to 1633
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   height/weight  1634 non-null   object
#  1   OPS            1634 non-null   float64
#  2   OBP            1634 non-null   float64
#  3   SLG            1634 non-null   float64
#  4   Height         1634 non-null   object
#  5   Weight         1634 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 76.7+ KB

# %%
regular_season_HW_OPS['Height'] = regular_season_HW_OPS['Height'].apply(float)
regular_season_HW_OPS['Weight'] = regular_season_HW_OPS['Weight'].apply(float)

# %%
regular_season_HW_OPS[:10]
# Out:
#   height/weight    OPS    OBP    SLG  Height  Weight
# 0    177cm/93kg  0.902  0.383  0.519   177.0    93.0
# 1    180cm/72kg  0.000  0.000  0.000   180.0    72.0
# 2    180cm/72kg  0.686  0.337  0.349   180.0    72.0
# 3    180cm/72kg  0.673  0.348  0.325   180.0    72.0
# 4    180cm/72kg  0.489  0.232  0.257   180.0    72.0
# 5    180cm/72kg  0.552  0.290  0.262   180.0    72.0
# 6    180cm/72kg  0.774  0.382  0.392   180.0    72.0
# 7    180cm/82kg  0.000  0.000  0.000   180.0    82.0
# 8    180cm/82kg  0.600  0.200  0.400   180.0    82.0
# 9    180cm/82kg  0.000  0.000  0.000   180.0    82.0

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,1,1)
sns.countplot(data = regular_season_HW_OPS, x = 'Height')
plt.xlabel('height')
plt.xticks(rotation = 90)
plt.show

plt.figure(figsize=(20,10))
plt.subplot(2,1,2)
sns.countplot(data = regular_season_HW_OPS, x = 'Weight')
plt.xlabel('Weight')
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
regular_season_HW_OPS['W/H'] = regular_season_HW_OPS['Weight'] / regular_season_HW_OPS['Height']

# %%
regular_season_HW_OPS
# Out:
#      height/weight    OPS    OBP    SLG  Height  Weight       W/H
# 0       177cm/93kg  0.902  0.383  0.519   177.0    93.0  0.525424
# 1       180cm/72kg  0.000  0.000  0.000   180.0    72.0  0.400000
# 2       180cm/72kg  0.686  0.337  0.349   180.0    72.0  0.400000
# 3       180cm/72kg  0.673  0.348  0.325   180.0    72.0  0.400000
# 4       180cm/72kg  0.489  0.232  0.257   180.0    72.0  0.400000
# ...            ...    ...    ...    ...     ...     ...       ...
# 1629    181cm/82kg  0.000  0.000  0.000   181.0    82.0  0.453039
# 1630    181cm/82kg  0.000  0.000  0.000   181.0    82.0  0.453039
# 1631    181cm/82kg  0.000  0.000  0.000   181.0    82.0  0.453039
# 1632    181cm/82kg  0.761  0.359  0.402   181.0    82.0  0.453039
# 1633    181cm/82kg  0.564  0.231  0.333   181.0    82.0  0.453039
#
# [1634 rows x 7 columns]

# %%
corr = regular_season_HW_OPS['W/H'].corr(regular_season_HW_OPS['OPS'])

# %%
sns.scatterplot(regular_season_HW_OPS['W/H'],
               regular_season_HW_OPS['OPS'],
               color = 'orange')

plt.title('W/H and OPS - corr : {}'.format(corr))
plt.xlabel("OPS", fontsize = 20)
plt.ylabel("W/H", fontsize = 20)
plt.grid()
plt.show()
# Out:
# C:\Users\woosung\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# findfont: Font family ['malgun'] not found. Falling back to DejaVu Sans.

# %%
regular_season_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2454 entries, 0 to 2453
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   batter_id        2454 non-null   int64
#  1   batter_name      2454 non-null   object
#  2   year             2454 non-null   int64
#  3   team             2454 non-null   object
#  4   avg              2428 non-null   float64
#  5   G                2454 non-null   int64
#  6   AB               2454 non-null   int64
#  7   R                2454 non-null   int64
#  8   H                2454 non-null   int64
#  9   2B               2454 non-null   int64
#  10  3B               2454 non-null   int64
#  11  HR               2454 non-null   int64
#  12  TB               2454 non-null   int64
#  13  RBI              2454 non-null   int64
#  14  SB               2454 non-null   int64
#  15  CS               2454 non-null   int64
#  16  BB               2454 non-null   int64
# ...

# %%
set(regular_season_df['starting_salary'])
# Out:
# {'100000달러',
#  '10000만원',
#  '11000만원',
#  '12000만원',
#  '13000만원',
#  '14000만원',
#  '15000만원',
#  '16000만원',
#  '17000만원',
#  '18000만원',
#  '20000만원',
#  '21000만원',
#  '23000만원',
#  '25000만원',
#  '27000만원',
#  '28000만원',
#  '300000달러',
#  '30000만원',
#  '3000만원',
#  '33000만원',
#  '4000만원',
#  '43000만원',
#  '45000만원',
#  '50000달러',
#  '5000만원',
#  '6000만원',
#  '6500만원',
#  '7000만원',
#  '8000만원',
#  '9000만원',
#  nan}
